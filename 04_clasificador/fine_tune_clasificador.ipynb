# %%
from pathlib import Path
import os
CLAS = Path(os.environ.get('TESIS_BASE', '/Users/ppizam/Claude/Master Thesis')) / 'Desarrollo/Metodologia/Clasificador'
exec(open(CLAS / 'celda_F0.py').read())
# Out:
# python: 3.13.9
# plataforma: macOS-26.5.2-arm64-arm-64bit-Mach-O
# arquitectura: arm64
# torch: 2.13.0
# transformers: 5.14.1
# datasets: 5.0.0
# accelerate: 1.14.0
# sklearn: 1.7.2
# pandas: 2.3.3
# numpy: 2.3.5
#
# MPS construido en este torch: True
# MPS disponible ahora mismo: True
#
# Todo instalado. Listo para la celda F1.

# %%
import sys
# !{sys.executable} -m pip install torch transformers datasets accelerate

# %%
exec(open(CLAS / 'celda_F1.py').read())
# Out:
# === muestra_grande_etiquetada (entrenamiento) ===
# filas: 11941
# columnas: ['anio', 'mes', 'sub', 'tipo', 'id', 'created_utc', 'ticker', 'n_tickers', 'texto', 'deepseek', 'openai', 'claude', 'etiqueta_equipo', 'votos', 'flag_empate']
# ...

# %%
exec(open(CLAS / 'celda_F2.py').read())
# Out:
# oro utilizable: 946 mensajes
# entrenamiento tras excluir 45 traslapados: 11896
#
# split: 10706 entrenamiento, 1190 validacion
# distribucion en entrenamiento:
# etiqueta_equipo
# neutral    5645
# compra     3936
# venta      1125
# distribucion en validacion:
# etiqueta_equipo
# neutral    628
# compra     437
# venta      125
#
# pesos por clase (compra, venta, neutral): [0.907 3.172 0.632]
#
# descargando StephanAkkerman/FinTwitBERT (la primera vez tarda; queda en cache local)...
# ...
# config.json:   0%|          | 0.00/640 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  439MB
# ...

# %%
exec(open(CLAS / 'celda_F3.py').read())
# Out:
# ...
# Map:   0%|          | 0/1190 [00:00<?, ? examples/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# datasets tokenizados: 10706 entrenamiento, 1190 validacion
# /opt/anaconda3/lib/python3.13/site-packages/torch/utils/data/dataloader.py:759: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='2010' max='2010' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2010/2010 1:59:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.697033</td>
#       <td>0.660633</td>
#       <td>0.670588</td>
# ...

# %%
exec(open(CLAS / 'celda_F4.py').read())
# Out:
# vara de oro: 946 mensajes (nunca vistos por el modelo)
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# modelo cargado desde disco | dispositivo: mps
#
# acuerdo global con la vara de oro: 72.0%
# f1 macro: 0.708
#
# reporte por clase:
#               precision    recall  f1-score   support
#
#       compra      0.723     0.787     0.754       395
#      neutral      0.777     0.689     0.730       334
#        venta      0.636     0.645     0.641       217
#
#     accuracy                          0.720       946
#    macro avg      0.712     0.707     0.708       946
# weighted avg      0.722     0.720     0.720       946
#
# matriz de confusion (filas = oro, columnas = prediccion):
#              pred_compra  pred_venta  pred_neutral
# oro_compra           311          38            46
# oro_venta             57         140            20
# oro_neutral           62          42           230
#
# acierto por fuente de etiqueta:
#   consenso_4de4: 84.7% (n=575)
# ...

# %%
exec(open(CLAS / 'celda_F5.py').read())
# Out:
# comparativo_finetune.csv creado con la fila de referencia de v1
# [v2a] base=StephanAkkerman/FinTwitBERT | 10706 entrenamiento, 1190 validacion, 946 oro
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: StephanAkkerman/FinTwitBERT
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# bert.pooler.dense.weight                   | MISSING    |
# classifier.weight                          | MISSING    |
# bert.pooler.dense.bias                     | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# ...

# %%
exec(open(CLAS / 'celda_F6.py').read())
# Out:
# [v2b] base=distilroberta-base | 10706 entrenamiento, 1190 validacion, 946 oro
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  331MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/101 [00:00<?, ?it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: distilroberta-base
# Key                         | Status     |
# ----------------------------+------------+-
# lm_head.dense.bias          | UNEXPECTED |
# lm_head.layer_norm.bias     | UNEXPECTED |
# roberta.pooler.dense.weight | UNEXPECTED |
# lm_head.bias                | UNEXPECTED |
# roberta.pooler.dense.bias   | UNEXPECTED |
# ...

# %%
exec(open(CLAS / 'celda_F7.py').read())
# Out:
# === comparativo de las tres variantes ===
# nombre                        base  epocas      lr  suavizado  dropout  minutos  f1_va  acc_va  acc_oro  f1_oro  acc_dificiles_oro
#     v1 StephanAkkerman/FinTwitBERT       3 0.00002        0.0      NaN    119.1 0.7161  0.7697     72.0  0.7080               41.5
#    v2a StephanAkkerman/FinTwitBERT       4 0.00001        0.1      0.2    144.6 0.6899  0.7361     68.0  0.6743               41.5
#    v2b          distilroberta-base       3 0.00002        0.0      NaN     42.4 0.7325  0.7697     70.2  0.6905               43.9
#
# prediciendo el oro con v1 y v2b...
# ...
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# acierto v1:  72.0% | f1 macro: 0.708
# acierto v2b: 70.2% | f1 macro: 0.690
# los dos modelos coinciden entre si en 78.4% de los mensajes
#
# duelos directos: ambos aciertan 582 | ambos fallan 183 | solo v1 acierta 99 | solo v2b acierta 82
# McNemar (binomial exacta sobre 181 discordantes): p = 0.2342
# ...

# %%
exec(open(CLAS / 'celda_F8.py').read())
# Out:
# eventos: 2,791 | tickers con ventana: 1,012 | dias-ticker validos: 84,725
# 2020-01: 14,739 filas mensaje-ticker en 0.1 min (acumulado 14,739)
# 2020-02: 84,302 filas mensaje-ticker en 0.2 min (acumulado 99,041)
# 2020-03: 71,185 filas mensaje-ticker en 0.4 min (acumulado 170,226)
# 2020-04: 110,752 filas mensaje-ticker en 0.3 min (acumulado 280,978)
# 2020-05: 137,740 filas mensaje-ticker en 0.2 min (acumulado 418,718)
# 2020-06: 175,544 filas mensaje-ticker en 0.3 min (acumulado 594,262)
# 2020-07: 149,634 filas mensaje-ticker en 0.3 min (acumulado 743,896)
# 2020-08: 99,735 filas mensaje-ticker en 0.2 min (acumulado 843,631)
# 2020-09: 101,971 filas mensaje-ticker en 0.2 min (acumulado 945,602)
# 2020-10: 50,852 filas mensaje-ticker en 0.2 min (acumulado 996,454)
# 2020-11: 201,947 filas mensaje-ticker en 0.2 min (acumulado 1,198,401)
# 2020-12: 178,486 filas mensaje-ticker en 0.3 min (acumulado 1,376,887)
# 2021-01: 1,641,242 filas mensaje-ticker en 1.4 min (acumulado 3,018,129)
# ...

# %%
exec(open(CLAS / 'celda_F9.py').read())
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# modelo v2b cargado | dispositivo: mps | clases: ['compra', 'venta', 'neutral']
# 78 meses en el corpus
#
# mensajes_2020_01.csv: 14,739 ya clasificadas, saltado
# mensajes_2020_02.csv: 84,302 ya clasificadas, saltado
# mensajes_2020_03.csv: 71,185 ya clasificadas, saltado
# mensajes_2020_04.csv: 110,752 ya clasificadas, saltado
# mensajes_2020_05.csv: 137,740 ya clasificadas, saltado
# mensajes_2020_06.csv: 175,544 ya clasificadas, saltado
# mensajes_2020_07.csv: 149,634 ya clasificadas, saltado
# mensajes_2020_08.csv: 99,735 ya clasificadas, saltado
# mensajes_2020_09.csv: 101,971 ya clasificadas, saltado
# mensajes_2020_10.csv: 50,852 ya clasificadas, saltado
# mensajes_2020_11.csv: 201,947 ya clasificadas, saltado
# mensajes_2020_12.csv: 178,486 ya clasificadas, saltado
# mensajes_2021_01.csv: 1,641,242 ya clasificadas, saltado
# mensajes_2021_02.csv: 848,602 ya clasificadas, saltado
# ...

# %%
exec(open(CLAS / 'celda_F10.py').read())
# Out:
# dias-ticker con al menos un mensaje clasificado: 66,871
# filas evento-dia del panel: 84,956 (2,791 eventos)
# guardado: panel_bt_eventos.csv (84,956 filas)
#
# cobertura: 76.7% de los dias de evento tienen al menos un mensaje
#
# estadisticas de B(t) en dias de evento (con mensajes):
#       b_duro  b_prob  d_duro  d_prob
# mean   1.246   1.060   0.358   0.427
# 25%    0.693   0.563   0.093   0.211
# 50%    1.204   1.051   0.316   0.389
# 75%    1.846   1.560   0.575   0.623
#
# correlacion b_duro vs b_prob (dias con mensajes): 0.9670
#
# ejemplo GME enero 2021 (dias -3 a 11):
#      fecha   fase  dia_evento  n_mensajes  m_compra  m_venta  b_duro  b_prob  d_duro
# 2021-01-10    pre          -3         483       271       41   1.868   1.694   0.263
# 2021-01-11    pre          -2        1893      1181      135   2.162   1.907   0.205
# 2021-01-12    pre          -1         960       574       47   2.483   2.010   0.151
# ...

# %%
exec(open(CLAS / 'celda_F11.py').read())
# Out:
# eventos: 2,791 | censurados el 2026-06-30: 6
# filas evento-dia: 45,882 | sin rezago disponible: 0
# dias sin direccion (dummy=1): 26.2%
# muertes observadas: 2,785 de 2,791 eventos
#
# === MODELO PRINCIPAL (B y D duros, rezago 1 dia) ===
#                      coef  exp(coef)  exp(coef) lower 95%  exp(coef) upper 95%       p
# covariate
# b_duro_lag        -0.0701     0.9323               0.8586               1.0123  0.0953
# d_duro_lag         0.5801     1.7861               1.3861               2.3016  0.0000
# sin_direccion_lag  0.1617     1.1755               1.0073               1.3717  0.0401
# log1p_n_lag        0.2712     1.3115               1.2760               1.3480  0.0000
#
# === ROBUSTEZ (B y D probabilisticos) ===
#                      coef  exp(coef)  exp(coef) lower 95%  exp(coef) upper 95%       p
# covariate
# b_prob_lag        -0.0843     0.9192               0.8103               1.0427  0.1904
# ...

# %%
exec(open(CLAS / 'celda_F12.py').read())
# Out:
# estimando especificaciones...
#   base (rezago 1): listo
#   rezago 2 dias: listo
#   rezago 3 dias: listo
#   sin regimen lento: listo
#   solo 2020-2021 (era GME): listo
#   solo 2022-2026: listo
#   estratificado por anio: listo
#   solo dias con >=5 direccionales: listo
#
# === ROBUSTEZ DEL HALLAZGO: HR del desacuerdo (D) y del optimismo (B) ===
# (HR_d > 1 = el desacuerdo de ayer aumenta el riesgo de muerte hoy)
#                  especificacion  n_filas  n_eventos  muertes  HR_d         IC_d    p_d  HR_b         IC_b    p_b
#                 base (rezago 1)    45882       2791     2785 1.786 [1.39, 2.30] 0.0000 0.932 [0.86, 1.01] 0.0953
#                   rezago 2 dias    45882       2791     2785 1.445 [1.14, 1.84] 0.0025 0.968 [0.90, 1.05] 0.4091
#                   rezago 3 dias    45882       2791     2785 1.380 [1.10, 1.73] 0.0053 0.969 [0.90, 1.04] 0.4057
#               sin regimen lento    44428       2779     2773 1.754 [1.36, 2.26] 0.0000 0.926 [0.85, 1.01] 0.0656
# ...

# %%
exec(open(CLAS / 'celda_F12b.py').read())
# Out:
# === filtro de senal minima dentro de cada era ===
#                        especificacion  n_filas  n_eventos  muertes  HR_d         IC_d    p_d  HR_b         IC_b    p_b
# era GME (2020-21) + >=5 direccionales    15872       1308     1183 3.213 [1.90, 5.44] 0.0000 1.122 [0.97, 1.30] 0.1342
#         2022-2026 + >=5 direccionales    12235       1128     1012 1.685 [0.93, 3.06] 0.0867 0.908 [0.74, 1.11] 0.3366
#
# === modelo de interaccion (muestra completa) ===
#                      coef  exp(coef)  exp(coef) lower 95%  exp(coef) upper 95%       p
# covariate
# d_duro_lag         0.3066     1.3589               0.9986               1.8491  0.0510
# d_x_gme            0.5037     1.6548               1.0974               2.4951  0.0162
# b_duro_lag        -0.1762     0.8385               0.7549               0.9312  0.0010
# b_x_gme            0.1975     1.2183               1.0791               1.3756  0.0014
# ...

# %%
# Celda F13
from pathlib import Path
import os
CLAS = Path(os.environ.get('TESIS_BASE', '/Users/ppizam/Claude/Master Thesis')) / 'Desarrollo/Metodologia/Clasificador'
exec(open(CLAS / 'celda_F13.py').read())
# Out:
# manifiesto existente recargado (submuestra_v1_eventos.csv); la permutacion NO se vuelve a sortear
# eventos seleccionados: 1,396 de 2,791 (50.0%) | era GME: 742 | 2022-26: 654
# tickers en la submuestra: 662 | dias-ticker validos: 41,168
#
# mensajes de la submuestra a clasificar con v1: 4,502,083 (57.3% del corpus de 7,856,262)
# ya clasificados en corridas previas: 4,224,838 | restantes: 277,245
# estimacion honesta a 35-90 msg/s: entre 0.9 y 2.2 horas (la velocidad real se mide sobre la marcha)
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# modelo v1 (FinTwitBERT) cargado | dispositivo: mps | clases: ['compra', 'venta', 'neutral']
# 78 meses en el corpus
#
# mensajes_2020_01.csv: 4,673 ya clasificadas, saltado
# mensajes_2020_02.csv: 55,236 ya clasificadas, saltado
# mensajes_2020_03.csv: 34,398 ya clasificadas, saltado
# mensajes_2020_04.csv: 48,800 ya clasificadas, saltado
# mensajes_2020_05.csv: 63,019 ya clasificadas, saltado
# ...

# %%
# Celda F14
from pathlib import Path
import os
CLAS = Path(os.environ.get('TESIS_BASE', '/Users/ppizam/Claude/Master Thesis')) / 'Desarrollo/Metodologia/Clasificador'
exec(open(CLAS / 'celda_F14.py').read())
# Out:
# submuestra: 1,396 eventos (manifiesto semilla 44)
# mensajes emparejados v1-v2b: 4,502,083 (de 4,502,083 clasificados por v1; deben coincidir)
#
# acuerdo por mensaje v1 vs v2b: 80.3%
# inversiones de direccion (compra<->venta): 5.85%
#
# matriz de confusion (% del total; filas = v2b, columnas = v1):
#          compra  venta  neutral
# compra    46.44   3.16     5.36
# venta      2.69   7.61     1.47
# neutral    5.25   1.77    26.24
#
# distribucion marginal en la submuestra (%):
#           v2b    v1
# compra   55.0  54.4
# venta    11.8  12.5
# neutral  33.3  33.1
#
# panel de la submuestra: 41,197 filas evento-dia
# sanidad n_mensajes identico por dia: 100.00% (esperado 100%)
#
# correlaciones entre series diarias (dias con mensajes, n=32,923):
#   b_duro: 0.8275 (n=32,923)
#   b_prob: 0.8970 (n=32,923)
#   d_duro: 0.7210 (n=31,167)
#   d_prob: 0.7996 (n=32,923)
# guardado: panel_bt_submuestra_dual.csv
#
# [v2b] filas start-stop: 21,653 | eventos: 1,396 | muertes: 1,393
#
# ...

# %%
# Celda F15
from pathlib import Path
import os
CLAS = Path(os.environ.get('TESIS_BASE', '/Users/ppizam/Claude/Master Thesis')) / 'Desarrollo/Metodologia/Clasificador'
exec(open(CLAS / 'celda_F15.py').read())
# Out:
# empates excluidos del entrenamiento: 127 (1.1% de la muestra)
# [v2c] base=distilroberta-base | 10593 entrenamiento, 1177 validacion, 946 oro
# ...
# Loading weights:   0%|          | 0/101 [00:00<?, ?it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: distilroberta-base
# Key                         | Status     |
# ----------------------------+------------+-
# lm_head.dense.weight        | UNEXPECTED |
# roberta.pooler.dense.bias   | UNEXPECTED |
# roberta.pooler.dense.weight | UNEXPECTED |
# lm_head.layer_norm.bias     | UNEXPECTED |
# lm_head.dense.bias          | UNEXPECTED |
# lm_head.bias                | UNEXPECTED |
# lm_head.layer_norm.weight   | UNEXPECTED |
# classifier.dense.bias       | MISSING    |
# classifier.out_proj.weight  | MISSING    |
# classifier.out_proj.bias    | MISSING    |
# classifier.dense.weight     | MISSING    |
#
# Notes:
# ...
