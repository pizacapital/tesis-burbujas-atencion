# %% [markdown]
# # Análisis multi-plataforma (lanzador)
#
# Cuaderno lanzador de las celdas MP1 (serie diaria X vs Reddit por ticker-evento) y MP2 (correlación cruzada con rezagos y desfase de picos). La lógica completa y su documentación viven en `celda_MP1.py` y `celda_MP2.py` de esta misma carpeta.

# %%
from pathlib import Path
MATRIX = Path('/Users/ppizam/Claude/Master Thesis/Desarrollo/Metodologia/Matrix')

# %%
exec(open(MATRIX / 'celda_MP1.py').read())
# Out:
# serie X: 2,412 dias-ticker | tweets unicos totales: 846,799
# dias sin dato de Reddit (fuera del rango de la matriz): 0
# guardado: serie_multiplataforma.csv (2,412 filas)
#
# correlacion Reddit-X por evento (log1p, mismo dia), 50 eventos:
#   mediana 0.901 | q25 0.820 | q75 0.928
#
# top 5 mas sincronizados:
# ticker
# GME     0.973
# BYND    0.962
# NOK     0.954
# SPCE    0.952
# RKT     0.950
#
# bottom 5 (plataformas desacopladas):
# ticker
# DJT     0.471
# DIS     0.414
# META    0.335
# TWTR    0.215
# CRSR   -0.060
#
# ejemplo GME (dias -3 a 8): reddit vs x
#      fecha   fase  dia_evento  reddit_menciones  x_tweets
# 2021-01-10    pre          -3               578         4
# 2021-01-11    pre          -2              2143       147
# 2021-01-12    pre          -1              1095        39
# 2021-01-13 evento           0             10102       742
# 2021-01-14 evento           1             13383       576
# 2021-01-15 evento           2             13740       306
# ...

# %%
exec(open(MATRIX / 'celda_MP2.py').read())
# Out:
# eventos analizados: 50
#
# === correlacion cruzada: mejor rezago por evento ===
# bando
# sincronico    49
# X adelanta     1
#
# distribucion del mejor rezago (k>0 = X adelanta):
# mejor_rezago
# 0    49
# 2     1
#
# mejor correlacion mediana: 0.901
#
# === desfase de picos (dias; negativo = X hace pico antes) ===
# mismo dia: 29 | X antes: 14 | Reddit antes: 7 | mediana: +0
#
# === por grupo (hipotesis: Reddit lidera en meme, X en institucional) ===
#                 n  rezago_medio pct_x_adelanta pct_reddit_adelanta  desfase_picos_mediano
# grupo
# institucional  28          0.00             0%                  0%                    0.0
# meme           22          0.09             5%                  0%                    0.0
#
# detalle por evento:
# ticker         grupo  n_dias  mejor_rezago  mejor_corr  desfase_picos      bando
#   AAPL institucional      70             0       0.901            -15 sincronico
# ...
